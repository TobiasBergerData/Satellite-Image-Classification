# %% [markdown]
# # Deep Learning Project

# %% [markdown]
# ### Import libraries

# %%
# Essential and common packages
import os
import glob

# Plots and bars
import matplotlib.pyplot as plt
import seaborn as sns

# Computation library
import numpy as np

# Tensorflow for building the resnet50 model
import tensorflow.python.keras as k
import tensorflow as tf
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, 
BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.initializers import random_uniform, glorot_uniform
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping


# Sklearn for confusion matrix
import itertools
from sklearn.metrics import confusion_matrix

# For visualization of plots without plt.show()
# %matplotlib inline

# %% [markdown]
# ### Define the required variable

# %% [markdown]
# The data set can be found here: https://github.com/phelber/EuroSAT

# %%
dataset_url = 'your location'
batch_size = 32
img_height = 64
img_width = 64
validation_split=0.2
rescale=1.0/255

# %% [markdown]
# ### Data Prep

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(validation_split=validation_split, rescale=rescale,   
    rotation_range=20,      # Randomly rotate images by up to 20 degrees
    width_shift_range=0.1,  # Randomly shift images horizontally by up to 10%
    height_shift_range=0.1, # Randomly shift images vertically by up to 10%
    shear_range=0.2,        # Shear intensity (shear angle in radians)
    zoom_range=0.2,         # Randomly zoom in/out on images by up to 20%
    horizontal_flip=True,   # Randomly flip images horizontally
    fill_mode='nearest'
   )
dataset = tf.keras.preprocessing.image_dataset_from_directory(dataset_url, image_size=(img_height, img_width), batch_size=batch_size, shuffle= True, seed=1)
# Out:
# Found 27000 files belonging to 10 classes.

# %%
train_dataset = datagen.flow_from_directory(batch_size=batch_size,
                                           directory=dataset_url,
                                           shuffle=True,
                                           target_size=(img_height, img_width),
                                           subset="training",
                                           class_mode='categorical')
# Out:
# Found 21600 images belonging to 10 classes.

# %%
test_dataset = datagen.flow_from_directory(batch_size=batch_size,
                                           directory=dataset_url,
                                           shuffle=True,
                                           target_size=(img_height, img_width),
                                           subset="validation",
                                           class_mode='categorical')
# Out:
# Found 5400 images belonging to 10 classes.

# %% [markdown]
# ### Visualization of inputs

# %%
class_names = dataset.class_names
plt.figure(figsize=(10, 10))
for images, labels in dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### ResNet50 Model

# %%
def identity_block(X, f, filters, training=True, initializer=random_uniform):
    """
    Implementation of the identity block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to random uniform initializer
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value.
    X_shortcut = X
    cache = []
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = 1, strides = (1, 1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training) # Default axis
    X = Activation('relu')(X)
    
    # Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1, 1), padding = 'same', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation('relu')(X)

    # Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1, 1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X_shortcut, X])
    X = X = Activation('relu')(X, training = training)

    return X

# %%
def convolutional_block(X, f, filters, s = 2, training=True, initializer=glorot_uniform):
    """
    Implementation of the convolutional block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    s -- Integer, specifying the stride to be used
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to Glorot uniform initializer, 
                   also called Xavier uniform initializer.
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    
    # First component of main path glorot_uniform(seed=0)
    X = Conv2D(filters = F1, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    
    # Second component of main path (≈3 lines)
    X = Conv2D(F2, (f, f), strides = (1, 1), padding = 'same', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation('relu')(X)

    # Third component of main path (≈2 lines)
    X = Conv2D(F3, (1, 1), strides = (1, 1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)

    ##### SHORTCUT PATH #### (≈2 lines)
    X_shortcut = Conv2D(F3, (1, 1), strides = (s, s), padding = 'valid', kernel_initializer = initializer(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3)(X_shortcut, training = training)

    # Final step: Add shortcut value to main path (Use this order [X, X_shortcut]), and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def ResNet50(input_shape = (64, 64, 3), classes = 6):
    """
    Stage-wise implementation of the architecture of the popular ResNet50:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> FLATTEN -> DENSE 

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], s = 1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])
    
   # Stage 3 (≈4 lines)
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], s = 2)
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])

    # Stage 4 (≈6 lines)
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], s = 2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])

    # Stage 5 (≈3 lines)
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], s = 2)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])

    # AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    X = AveragePooling2D(pool_size = (2, 2), name = 'avg_pool')(X)
    

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X)

    return model

# %% [markdown]
# ### Model training

# %%
model = ResNet50(input_shape=(64,64,3), classes=10)
model.summary( )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 70, 70, 3)            0         ['input_1[0][0]']
#  g2D)
#
#  conv2d (Conv2D)             (None, 32, 32, 64)           9472      ['zero_padding2d[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 64)           0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 64)           0         ['activation[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 15, 15, 64)           4160      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 15, 15, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)           36928     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 15, 15, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)          16640     ['activation_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 256)          16640     ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 15, 15, 256)          1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 15, 15, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 15, 15, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  activation_3 (Activation)   (None, 15, 15, 256)          0         ['add[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 15, 15, 64)           16448     ['activation_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 15, 15, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 15, 15, 64)           36928     ['activation_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 15, 15, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 15, 15, 256)          16640     ['activation_5[0][0]']
#
#  batch_normalization_7 (Bat  (None, 15, 15, 256)          1024      ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 15, 15, 256)          0         ['activation_3[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 15, 15, 256)          0         ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 15, 15, 64)           16448     ['activation_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 15, 15, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 15, 15, 64)           36928     ['activation_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 15, 15, 64)           256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 15, 15, 256)          16640     ['activation_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 15, 15, 256)          1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 15, 15, 256)          0         ['activation_6[0][0]',
#                                                                      'batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_9 (Activation)   (None, 15, 15, 256)          0         ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)            32896     ['activation_9[0][0]']
#
#  batch_normalization_11 (Ba  (None, 8, 8, 128)            512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_10[0][0]']
#
#  batch_normalization_12 (Ba  (None, 8, 8, 128)            512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_11[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 512)            131584    ['activation_9[0][0]']
#
#  batch_normalization_13 (Ba  (None, 8, 8, 512)            2048      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 8, 8, 512)            2048      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 8, 8, 512)            0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 8, 8, 512)            0         ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_12[0][0]']
#
#  batch_normalization_15 (Ba  (None, 8, 8, 128)            512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_13[0][0]']
#
#  batch_normalization_16 (Ba  (None, 8, 8, 128)            512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_14[0][0]']
#
#  batch_normalization_17 (Ba  (None, 8, 8, 512)            2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 8, 8, 512)            0         ['activation_12[0][0]',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 8, 8, 512)            0         ['add_4[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_15[0][0]']
#
#  batch_normalization_18 (Ba  (None, 8, 8, 128)            512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_16[0][0]']
#
#  batch_normalization_19 (Ba  (None, 8, 8, 128)            512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_17[0][0]']
#
#  batch_normalization_20 (Ba  (None, 8, 8, 512)            2048      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 8, 8, 512)            0         ['activation_15[0][0]',
#                                                                      'batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 8, 8, 512)            0         ['add_5[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_18[0][0]']
#
#  batch_normalization_21 (Ba  (None, 8, 8, 128)            512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_19[0][0]']
#
#  batch_normalization_22 (Ba  (None, 8, 8, 128)            512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_20[0][0]']
#
#  batch_normalization_23 (Ba  (None, 8, 8, 512)            2048      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 8, 8, 512)            0         ['activation_18[0][0]',
#                                                                      'batch_normalization_23[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 8, 8, 512)            0         ['add_6[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 256)            131328    ['activation_21[0][0]']
#
#  batch_normalization_24 (Ba  (None, 4, 4, 256)            1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_22[0][0]']
#
#  batch_normalization_25 (Ba  (None, 4, 4, 256)            1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_23[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 4, 4, 1024)           525312    ['activation_21[0][0]']
#
#  batch_normalization_26 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 4, 4, 1024)           0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 4, 4, 1024)           0         ['add_7[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_24[0][0]']
#
#  batch_normalization_28 (Ba  (None, 4, 4, 256)            1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_25[0][0]']
#
#  batch_normalization_29 (Ba  (None, 4, 4, 256)            1024      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_26[0][0]']
#
#  batch_normalization_30 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 4, 4, 1024)           0         ['activation_24[0][0]',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 4, 4, 1024)           0         ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_27[0][0]']
#
#  batch_normalization_31 (Ba  (None, 4, 4, 256)            1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_28[0][0]']
#
#  batch_normalization_32 (Ba  (None, 4, 4, 256)            1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_29[0][0]']
#
#  batch_normalization_33 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 4, 4, 1024)           0         ['activation_27[0][0]',
#                                                                      'batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_30 (Activation)  (None, 4, 4, 1024)           0         ['add_9[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_30[0][0]']
#
#  batch_normalization_34 (Ba  (None, 4, 4, 256)            1024      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_31[0][0]']
#
#  batch_normalization_35 (Ba  (None, 4, 4, 256)            1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_32[0][0]']
#
#  batch_normalization_36 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 4, 4, 1024)           0         ['activation_30[0][0]',
#                                                                      'batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 4, 4, 1024)           0         ['add_10[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_33[0][0]']
#
#  batch_normalization_37 (Ba  (None, 4, 4, 256)            1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_34[0][0]']
#
#  batch_normalization_38 (Ba  (None, 4, 4, 256)            1024      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_35[0][0]']
#
#  batch_normalization_39 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 4, 4, 1024)           0         ['activation_33[0][0]',
#                                                                      'batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 4, 4, 1024)           0         ['add_11[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_36[0][0]']
#
#  batch_normalization_40 (Ba  (None, 4, 4, 256)            1024      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_37[0][0]']
#
#  batch_normalization_41 (Ba  (None, 4, 4, 256)            1024      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_38[0][0]']
#
#  batch_normalization_42 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 4, 4, 1024)           0         ['activation_36[0][0]',
#                                                                      'batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 4, 4, 1024)           0         ['add_12[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 2, 2, 512)            524800    ['activation_39[0][0]']
#
#  batch_normalization_43 (Ba  (None, 2, 2, 512)            2048      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_40[0][0]']
#
#  batch_normalization_44 (Ba  (None, 2, 2, 512)            2048      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_41[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 2, 2, 2048)           2099200   ['activation_39[0][0]']
#
#  batch_normalization_45 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 2, 2, 2048)           0         ['batch_normalization_45[0][0]
#                                                                     ',
#                                                                      'batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 2, 2, 2048)           0         ['add_13[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 2, 2, 512)            1049088   ['activation_42[0][0]']
#
#  batch_normalization_47 (Ba  (None, 2, 2, 512)            2048      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_43[0][0]']
#
#  batch_normalization_48 (Ba  (None, 2, 2, 512)            2048      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_44[0][0]']
#
#  batch_normalization_49 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_49[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 2, 2, 2048)           0         ['activation_42[0][0]',
#                                                                      'batch_normalization_49[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 2, 2, 2048)           0         ['add_14[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 2, 2, 512)            1049088   ['activation_45[0][0]']
#
#  batch_normalization_50 (Ba  (None, 2, 2, 512)            2048      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_46[0][0]']
#
#  batch_normalization_51 (Ba  (None, 2, 2, 512)            2048      ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_47[0][0]']
#
#  batch_normalization_52 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 2, 2, 2048)           0         ['activation_45[0][0]',
#                                                                      'batch_normalization_52[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 2, 2, 2048)           0         ['add_15[0][0]']
#
#  avg_pool (AveragePooling2D  (None, 1, 1, 2048)           0         ['activation_48[0][0]']
#  )
#
#  flatten (Flatten)           (None, 2048)                 0         ['avg_pool[0][0]']
#
#  dense (Dense)               (None, 10)                   20490     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23608202 (90.06 MB)
# Trainable params: 23555082 (89.86 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Installing an early stopping mechanism

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)

# %% [markdown]
# ### Determining the optimizer

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# please increase the epoch for higher accuracy (epochs=100)
history = model.fit(train_dataset, validation_data=test_dataset, epochs=20, batch_size=32, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 675/675 [==============================] - 1055s 2s/step - loss: 1.6332 - accuracy: 0.4999 - val_loss: 1.1491 - val_accuracy: 0.6150
# Epoch 2/20
# 675/675 [==============================] - 1001s 1s/step - loss: 0.9963 - accuracy: 0.6651 - val_loss: 1.4086 - val_accuracy: 0.5219
# Epoch 3/20
# 675/675 [==============================] - 1001s 1s/step - loss: 0.9242 - accuracy: 0.6879 - val_loss: 0.8836 - val_accuracy: 0.7007
# Epoch 4/20
# 675/675 [==============================] - 1007s 1s/step - loss: 0.9806 - accuracy: 0.6780 - val_loss: 1.7311 - val_accuracy: 0.5772
# Epoch 5/20
# 675/675 [==============================] - 1007s 1s/step - loss: 0.9781 - accuracy: 0.6890 - val_loss: 0.7726 - val_accuracy: 0.7333
# Epoch 6/20
# 675/675 [==============================] - 1007s 1s/step - loss: 0.9262 - accuracy: 0.7030 - val_loss: 0.9437 - val_accuracy: 0.6656
# Epoch 7/20
# 675/675 [==============================] - 1011s 1s/step - loss: 0.8082 - accuracy: 0.7324 - val_loss: 0.7236 - val_accuracy: 0.7483
# Epoch 8/20
# 675/675 [==============================] - 1005s 1s/step - loss: 0.6643 - accuracy: 0.7742 - val_loss: 0.5810 - val_accuracy: 0.7998
# Epoch 9/20
# 675/675 [==============================] - 1000s 1s/step - loss: 0.6525 - accuracy: 0.7875 - val_loss: 0.6096 - val_accuracy: 0.7965
# Epoch 10/20
# 675/675 [==============================] - 991s 1s/step - loss: 0.6320 - accuracy: 0.7970 - val_loss: 0.6176 - val_accuracy: 0.8148
# Epoch 11/20
# 675/675 [==============================] - 992s 1s/step - loss: 0.6331 - accuracy: 0.8000 - val_loss: 0.6130 - val_accuracy: 0.8163
# Epoch 12/20
# 675/675 [==============================] - 993s 1s/step - loss: 0.6127 - accuracy: 0.8067 - val_loss: 1.7308 - val_accuracy: 0.5417
# Epoch 13/20
# 675/675 [==============================] - 998s 1s/step - loss: 0.5790 - accuracy: 0.8102 - val_loss: 0.6407 - val_accuracy: 0.7950
# Epoch 14/20
# 675/675 [==============================] - 1023s 2s/step - loss: 0.4851 - accuracy: 0.8414 - val_loss: 0.4471 - val_accuracy: 0.8487
# Epoch 15/20
# 675/675 [==============================] - 986s 1s/step - loss: 0.4931 - accuracy: 0.8379 - val_loss: 0.4826 - val_accuracy: 0.8359
# Epoch 16/20
# 675/675 [==============================] - 983s 1s/step - loss: 0.4316 - accuracy: 0.8578 - val_loss: 0.4187 - val_accuracy: 0.8706
# Epoch 17/20
# 675/675 [==============================] - 982s 1s/step - loss: 0.4322 - accuracy: 0.8595 - val_loss: 0.4672 - val_accuracy: 0.8454
# Epoch 18/20
# 675/675 [==============================] - 981s 1s/step - loss: 0.3941 - accuracy: 0.8663 - val_loss: 0.6371 - val_accuracy: 0.7902
# Epoch 19/20
# 675/675 [==============================] - 982s 1s/step - loss: 0.5058 - accuracy: 0.8386 - val_loss: 0.5378 - val_accuracy: 0.8478
# Epoch 20/20
# 675/675 [==============================] - 984s 1s/step - loss: 0.4070 - accuracy: 0.8658 - val_loss: 0.3892 - val_accuracy: 0.8715

# %%
model.save('lulc_50 epochs_4 layer_27000pics_patience 15_with imageaugmentation.h5')
# Out:
# c:\Users\tobia\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### Load model

# %%
#from tensorflow.keras.models import load_model
#model = load_model(r"lulc_5_epoch.h5")
#history = model

# %% [markdown]
# ### Analyzing results

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16.53, 11.69))
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_xlabel('epoch')
ax1.set_ylabel('accuracy')
ax1.set_title('Accuracy over epoch')
ax1.legend(['Train', 'Test'], loc='upper left')

ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_xlabel('epoch')
ax2.set_ylabel('loss')
ax2.set_title('Loss over epoch')
ax2.legend(['Train', 'Test'], loc="upper right")

# %% [markdown]
# ### Confusion matrix

# %%
y_pred = []  # store predicted labels
y_true = []  # store true labels

# iterate over the dataset
for i, (image_batch, label_batch) in enumerate(test_dataset):   # use dataset.unbatch() with repeat
    # append true labels
    y_true.append(label_batch)
    # compute predictions
    preds = model.predict(image_batch)
    # append predicted labels
    y_pred.append(np.argmax(preds, axis =  1))
    if i==300:
        break

# convert the true and predicted labels into tensors
correct_labels = tf.concat([item for item in y_true], axis = 0)
correct_labels = np.argmax(correct_labels, axis=1)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)
# Out:
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 1s 900ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 183ms/step

# %%
cm = confusion_matrix(correct_labels, predicted_labels)
cm
# Out:
# array([[ 984,    8,    8,    1,    0,   13,   16,    1,   23,    8],
#        [   1, 1014,    7,    0,    0,   11,    1,    0,    4,   23],
#        [  50,   37,  865,    5,    5,   15,   64,    5,   15,    3],
#        [  40,    1,   17,  673,   45,   21,   37,   17,   46,    1],
#        [   2,    0,   18,   19,  820,    0,    8,   31,    7,    0],
#        [  25,   60,   15,    4,    0,  553,   17,    0,   29,    7],
#        [ 115,    1,   72,    9,    5,   30,  631,    3,   23,    0],
#        [   0,    0,   46,   11,   27,    1,   40,  947,    0,    0],
#        [  29,    5,    8,   28,    7,   16,   11,    1,  769,    6],
#        [   9,    5,    0,    0,    0,    2,    0,    0,   10, 1057]],
#       dtype=int64)

# %%
def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        figsize=(10, 10),
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=figsize)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title('ResNet 20 Epochs / Four Layers with Aug')

# %%
plot_confusion_matrix(cm, train_dataset.class_indices, cmap='Reds')
# Out:
# Confusion matrix, without normalization
# [[ 984    8    8    1    0   13   16    1   23    8]
#  [   1 1014    7    0    0   11    1    0    4   23]
#  [  50   37  865    5    5   15   64    5   15    3]
#  [  40    1   17  673   45   21   37   17   46    1]
#  [   2    0   18   19  820    0    8   31    7    0]
#  [  25   60   15    4    0  553   17    0   29    7]
#  [ 115    1   72    9    5   30  631    3   23    0]
#  [   0    0   46   11   27    1   40  947    0    0]
#  [  29    5    8   28    7   16   11    1  769    6]
#  [   9    5    0    0    0    2    0    0   10 1057]]
